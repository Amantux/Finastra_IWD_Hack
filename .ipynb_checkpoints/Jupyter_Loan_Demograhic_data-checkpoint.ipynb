# %%
import os
import sys
import numpy as np
import pandas as pd

# %%
#Load in your data
Customer_Demo = pd.read_excel('customer_demographics.xlsx', keep_default_na=False, na_values=[""])
Customer_Loan = pd.read_excel('customer_loans.xlsx', keep_default_na=False, na_values=[""])

# %%
#Check your data
print(Customer_Demo.head())
print("\n---------------------------------------------------------------------------------------------------")
print(Customer_Loan.head())
# Out:
#      custid              Name                                           Job  \
# 0  92886957  Barbara Thompson  Automotive Service Technicians and Mechanics
# 1  16462625        James Wade                               Prosthodontists
# 2  89457436      Joel Jackson                                      Surgeons
# 3  68462543    Tyler Clements                       Physicians and Surgeons
# 4  63315493     Adam Stephens  Railroad Brake, Signal, and Switch Operators
#
#    Age       Lat       Long  Income  CreditScore  HouseholdSize  ZipCode  \
# 0   39  31.84568 -102.36764   43415          658              4    79761
# 1   93  42.73920  -84.62081  564164          786              4    48917
# 2   99  44.27804  -88.27205  466344          676              1    54140
# 3  100  33.50921 -111.89903  756171          694              2    85250
# 4   97  33.93113 -117.54866   58948          688              2    92860
#
# ...

# %%
#Create your merged df
Merged_Loan_Data = pd.merge(left=Customer_Demo, right=Customer_Loan, left_on='custid', right_on='custid')

# %%
print(Merged_Loan_Data.head())
# Out:
#      custid              Name                                           Job  \
# 0  92886957  Barbara Thompson  Automotive Service Technicians and Mechanics
# 1  16462625        James Wade                               Prosthodontists
# 2  89457436      Joel Jackson                                      Surgeons
# 3  68462543    Tyler Clements                       Physicians and Surgeons
# 4  63315493     Adam Stephens  Railroad Brake, Signal, and Switch Operators
#
#    Age       Lat       Long  Income_x  CreditScore_x  HouseholdSize  ZipCode  \
# 0   39  31.84568 -102.36764     43415            658              4    79761
# 1   93  42.73920  -84.62081    564164            786              4    48917
# 2   99  44.27804  -88.27205    466344            676              1    54140
# 3  100  33.50921 -111.89903    756171            694              2    85250
# 4   97  33.93113 -117.54866     58948            688              2    92860
#
# ...

# %%
#Now to add in localisation
#import geopy # Location to ZIp Code
import surgeo #Zip + Name to race

# %%
#Lets start assuming Zip Code and lat long are same
fsg = surgeo.BIFSGModel() #Model taking first and last name, zip

# %%
#Prepare First and last Name as well as title and stuff
from nameparser import HumanName

# %%
Merged_Loan_Data["title"] = Merged_Loan_Data["Name"].apply(lambda x: HumanName(x).title)
Merged_Loan_Data["first"] = Merged_Loan_Data["Name"].apply(lambda x: HumanName(x).first)
Merged_Loan_Data["middle"] = Merged_Loan_Data["Name"].apply(lambda x: HumanName(x).middle)
Merged_Loan_Data["last"] = Merged_Loan_Data["Name"].apply(lambda x: HumanName(x).last)
Merged_Loan_Data["suffix"] = Merged_Loan_Data["Name"].apply(lambda x: HumanName(x).suffix)
Merged_Loan_Data["nickname"] = Merged_Loan_Data["Name"].apply(lambda x: HumanName(x).nickname)

# %%
Merged_Loan_Data.head()
# Out:
#      custid              Name                                           Job  \
# 0  92886957  Barbara Thompson  Automotive Service Technicians and Mechanics
# 1  16462625        James Wade                               Prosthodontists
# 2  89457436      Joel Jackson                                      Surgeons
# 3  68462543    Tyler Clements                       Physicians and Surgeons
# 4  63315493     Adam Stephens  Railroad Brake, Signal, and Switch Operators
#
#    Age       Lat       Long  Income_x  CreditScore_x  HouseholdSize  ZipCode  \
# 0   39  31.84568 -102.36764     43415            658              4    79761
# 1   93  42.73920  -84.62081    564164            786              4    48917
# 2   99  44.27804  -88.27205    466344            676              1    54140
# 3  100  33.50921 -111.89903    756171            694              2    85250
# 4   97  33.93113 -117.54866     58948            688              2    92860
#
# ...

# %%
fsg_results = fsg.get_probabilities(Merged_Loan_Data["first"], Merged_Loan_Data["last"], Merged_Loan_Data["ZipCode"])

# %%
fsg_results['Max'] = fsg_results[fsg_results.columns.difference(['first_name', 'surname', 'zcta5'])].idxmax(axis=1)

# %%
print(fsg_results.head())
fsg_results['first_name'] = fsg_results['first_name'].str.capitalize()
fsg_results['surname'] = fsg_results['surname'].str.capitalize()
# Out:
#    zcta5 first_name   surname     white     black       api    native  \
# 0  79761    BARBARA  THOMPSON  0.780611  0.191603  0.000039  0.004014
# 1  48917      JAMES      WADE  0.833131  0.143230  0.000237  0.001976
# 2  54140       JOEL   JACKSON  0.969914  0.012615  0.000100  0.004491
# 3  85250      TYLER  CLEMENTS  0.987164  0.000207  0.000058  0.002820
# 4  92860       ADAM  STEPHENS  0.963161  0.013266  0.000187  0.001638
#
#    multiple  hispanic    Max
# 0  0.006841  0.016891  white
# 1  0.020651  0.000774  white
# 2  0.006402  0.006478  white
# 3  0.009337  0.000414  white
# 4  0.013271  0.008477  white

# %%
fsg_results['zcta5']=fsg_results['zcta5'].astype(int)
fsg_results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48675 entries, 0 to 48674
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   zcta5       48675 non-null  int32
#  1   first_name  48675 non-null  object
#  2   surname     48675 non-null  object
#  3   white       48506 non-null  float64
#  4   black       48506 non-null  float64
#  5   api         48506 non-null  float64
#  6   native      48506 non-null  float64
#  7   multiple    48506 non-null  float64
#  8   hispanic    48506 non-null  float64
#  9   Max         48506 non-null  object
# dtypes: float64(6), int32(1), object(3)
# memory usage: 3.5+ MB

# %%
Merged_Loan_Data_2 = pd.merge(left=Merged_Loan_Data, right=fsg_results, left_on=['first','last','ZipCode'], right_on=['first_name','surname','zcta5'])

# %%
Merged_Loan_Data_2.head()
# Out:
#      custid              Name                                           Job  \
# 0  92886957  Barbara Thompson  Automotive Service Technicians and Mechanics
# 1  16462625        James Wade                               Prosthodontists
# 2  89457436      Joel Jackson                                      Surgeons
# 3  68462543    Tyler Clements                       Physicians and Surgeons
# 4  63315493     Adam Stephens  Railroad Brake, Signal, and Switch Operators
#
#    Age       Lat       Long  Income_x  CreditScore_x  HouseholdSize  ZipCode  \
# 0   39  31.84568 -102.36764     43415            658              4    79761
# 1   93  42.73920  -84.62081    564164            786              4    48917
# 2   99  44.27804  -88.27205    466344            676              1    54140
# 3  100  33.50921 -111.89903    756171            694              2    85250
# 4   97  33.93113 -117.54866     58948            688              2    92860
#
# ...

# %%
import seaborn as sns
sns.countplot(Merged_Loan_Data_2['Max'],label="Count")

# %%
import gender_guesser.detector as gender #Gender Guesser

# %%
d = gender.Detector()
print(d.get_gender(u"Alex")) #Test the package
Merged_Loan_Data_2["Gender"] = Merged_Loan_Data_2["first_name"].apply(lambda x: d.get_gender(x)) #apply it to each first name column in every row
Merged_Loan_Data_2.columns
# Out:
# male
# Index(['custid', 'Name', 'Job', 'Age', 'Lat', 'Long', 'Income_x',
#        'CreditScore_x', 'HouseholdSize', 'ZipCode', 'MajorCity', 'State',
#        'MedianHomeValue', 'MedianHouseholdIncome', 'Debt_x', 'Income_y',
#        'CreditScore_y', 'Debt_y', 'Date', 'LoanTerm', 'InterestRate',
#        'CreditIncidents', 'HomeValue', 'LoanAmount', 'ProductType',
#        'LoanStatus', 'title', 'first', 'middle', 'last', 'suffix', 'nickname',
#        'zcta5', 'first_name', 'surname', 'white', 'black', 'api', 'native',
#        'multiple', 'hispanic', 'Max', 'Gender'],
#       dtype='object')

# %%
Merged_Loan_Data_2.head()
# Out:
#      custid              Name                                           Job  \
# 0  92886957  Barbara Thompson  Automotive Service Technicians and Mechanics
# 1  16462625        James Wade                               Prosthodontists
# 2  89457436      Joel Jackson                                      Surgeons
# 3  68462543    Tyler Clements                       Physicians and Surgeons
# 4  63315493     Adam Stephens  Railroad Brake, Signal, and Switch Operators
#
#    Age       Lat       Long  Income_x  CreditScore_x  HouseholdSize  ZipCode  \
# 0   39  31.84568 -102.36764     43415            658              4    79761
# 1   93  42.73920  -84.62081    564164            786              4    48917
# 2   99  44.27804  -88.27205    466344            676              1    54140
# 3  100  33.50921 -111.89903    756171            694              2    85250
# 4   97  33.93113 -117.54866     58948            688              2    92860
#
# ...

# %%
sns.countplot(Merged_Loan_Data_2['ProductType'],label="Count")

# %%
Merged_Loan_Data_2['Debt_Asset_ratio'] = Merged_Loan_Data_2['HomeValue']/Merged_Loan_Data_2['LoanAmount']
Merged_Loan_Data_2['Home_Value_Against_median'] = Merged_Loan_Data_2['HomeValue']/Merged_Loan_Data_2['MedianHomeValue']
Merged_Loan_Data_2['Income_Vs_Avg'] = Merged_Loan_Data_2['Income_x']/Merged_Loan_Data_2['MedianHouseholdIncome']

Merged_Loan_Data_2.columns
Merged_Loan_Data_2.to_csv(r'Merged_Loan_Data_2.csv', index = False)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder
from sklearn.preprocessing import LabelEncoder
enc = OneHotEncoder(handle_unknown='ignore')
enc2 = OneHotEncoder(handle_unknown='ignore')



sns.countplot(Merged_Loan_Data_2['Max'],label="Count")

# %%
Merged_Loan_Data_2.columns
# Out:
# Index(['custid', 'Name', 'Job', 'Age', 'Lat', 'Long', 'Income_x',
#        'CreditScore_x', 'HouseholdSize', 'ZipCode', 'MajorCity', 'State',
#        'MedianHomeValue', 'MedianHouseholdIncome', 'Debt_x', 'Income_y',
#        'CreditScore_y', 'Debt_y', 'Date', 'LoanTerm', 'InterestRate',
#        'CreditIncidents', 'HomeValue', 'LoanAmount', 'ProductType',
#        'LoanStatus', 'title', 'first', 'middle', 'last', 'suffix', 'nickname',
#        'zcta5', 'first_name', 'surname', 'white', 'black', 'api', 'native',
#        'multiple', 'hispanic', 'Max', 'Gender', 'Debt_Asset_ratio',
#        'Home_Value_Against_median', 'Income_Vs_Avg'],
#       dtype='object')

# %%
Tracked_Features = ['Race','Gender','Job', 'CreditScore', 'ProductType', 'Age', 'LoanTerm','ZipCode', 'InterestRate']
labelencoder = LabelEncoder()
gender_encoder = LabelEncoder()
title_encoder = LabelEncoder()
product_type_encoder = LabelEncoder()
#Scale & One hot encode the data set
Analyze_DF = pd.DataFrame()
Analyze_DF['Race'] = labelencoder.fit_transform(Merged_Loan_Data_2['Max'].astype(str))
Analyze_DF['Gender'] = gender_encoder.fit_transform(Merged_Loan_Data_2['Gender'].astype(str))
Analyze_DF['Job'] = title_encoder.fit_transform(Merged_Loan_Data_2['Job'].astype(str))
Analyze_DF['Age'] = Merged_Loan_Data_2['Age']
Analyze_DF['CreditScore'] = Merged_Loan_Data_2['CreditScore_x']
Analyze_DF['ProductType'] = title_encoder.fit_transform(Merged_Loan_Data_2['ProductType'].astype(str))
Analyze_DF['LoanTerm'] = Merged_Loan_Data_2['LoanTerm']
Analyze_DF['ZipCode'] = Merged_Loan_Data_2['ZipCode']
Analyze_DF['InterestRate'] = Merged_Loan_Data_2['InterestRate']
Analyze_DF
# Out:
#        Race  Gender  Job  Age  CreditScore  ProductType  LoanTerm  ZipCode  \
# 0         6       1   72   39          658            2       180    79761
# 1         6       2  832   93          786            1       480    48917
# 2         6       2  963   99          676            2       180    54140
# 3         6       4  785  100          694            2       180    85250
# 4         6       2  857   97          688            2       420    92860
# ...     ...     ...  ...  ...          ...          ...       ...      ...
# 49380     2       2  713   19          621            1       180    60014
# 49381     6       2  832   35          796            0       480    85250
# 49382     6       2  858   94          706            2       420    75601
# 49383     6       1  128   28          628            0       480    60014
# 49384     6       3  555   95          647            3       420    92705
#
#        InterestRate
# 0             0.036
# 1             0.038
# ...

# %%
Merged_Loan_Data_2.groupby(['Gender','LoanStatus']).size()
# Out:
# Gender         LoanStatus
# andy           Approved        111
#                Rejected         28
# female         Approved      16206
#                Rejected       4666
# male           Approved      18032
#                Rejected       5179
# mostly_female  Approved       2655
#                Rejected        750
# mostly_male    Approved       1334
#                Rejected        399
# unknown        Approved         23
#                Rejected          2
# dtype: int64

# %%
Merged_Loan_Data_2.groupby(['Max','LoanStatus']).size()
# Out:
# Max       LoanStatus
# api       Approved        487
#           Rejected        136
# black     Approved       3801
#           Rejected        864
# hispanic  Approved       4202
#           Rejected       1228
# multiple  Approved        110
#           Rejected         29
# native    Approved          9
#           Rejected          2
# white     Approved      29621
#           Rejected       8723
# dtype: int64

# %%
X = Analyze_DF[Tracked_Features] #Take a subset of only the tracked features
y = Merged_Loan_Data_2['LoanStatus'].map({'Approved': '1', 'Rejected': '0'})
pd.options.mode.chained_assignment = None #Silence the error message for combining slices

scaler = MinMaxScaler() 

# creating instance of labelencoder

#Add in extra metrics

X['Income'] = (scaler.fit_transform(Merged_Loan_Data_2[['Income_x']]))
X['Income_Scaled'] = (scaler.fit_transform(Merged_Loan_Data_2[['Income_Vs_Avg']]))
X['DAR'] = (scaler.fit_transform(Merged_Loan_Data_2[['Debt_Asset_ratio']]))
X['HVAM'] = (scaler.fit_transform(Merged_Loan_Data_2[['Home_Value_Against_median']]))
X['Credit_Incidents']= (scaler.fit_transform(Merged_Loan_Data_2[['CreditIncidents']]))

X
# Out:
#        Race  Gender  Job  CreditScore  ProductType  Age  LoanTerm  ZipCode  \
# 0         6       1   72          658            2   39       180    79761
# 1         6       2  832          786            1   93       480    48917
# 2         6       2  963          676            2   99       180    54140
# 3         6       4  785          694            2  100       180    85250
# 4         6       2  857          688            2   97       420    92860
# ...     ...     ...  ...          ...          ...  ...       ...      ...
# 49380     2       2  713          621            1   19       180    60014
# 49381     6       2  832          796            0   35       480    85250
# 49382     6       2  858          706            2   94       420    75601
# 49383     6       1  128          628            0   28       480    60014
# 49384     6       3  555          647            3   95       420    92705
#
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0) #Split into train and test data

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
logreg.fit(X_train, y_train)
print('Accuracy of Logistic regression classifier on training set: {:.2f}'
     .format(logreg.score(X_train, y_train)))
print('Accuracy of Logistic regression classifier on test set: {:.2f}'
     .format(logreg.score(X_test, y_test)))
# Out:
# Accuracy of Logistic regression classifier on training set: 0.78
# Accuracy of Logistic regression classifier on test set: 0.77
# C:\Users\Aman\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier().fit(X_train, y_train)
print('Accuracy of Decision Tree classifier on training set: {:.2f}'
     .format(clf.score(X_train, y_train)))
print('Accuracy of Decision Tree classifier on test set: {:.2f}'
     .format(clf.score(X_test, y_test)))
# Out:
# Accuracy of Decision Tree classifier on training set: 1.00
# Accuracy of Decision Tree classifier on test set: 0.96

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()

knn.fit(X_train, y_train)
print('Accuracy of K-NN classifier on training set: {:.2f}'
     .format(knn.score(X_train, y_train)))
print('Accuracy of K-NN classifier on test set: {:.2f}'
     .format(knn.score(X_test, y_test)))
# Out:
# Accuracy of K-NN classifier on training set: 0.83
# Accuracy of K-NN classifier on test set: 0.77

# %%
from fairlearn.metrics import MetricFrame
from sklearn.metrics import accuracy_score

# %%
#Start metrics and scoring for the DecisionTreeClassifier as it had the highest test score
y_pred = clf.predict(X)
gm = MetricFrame(accuracy_score, y, y_pred, sensitive_features=X['Gender'])

# %%
print(gm.overall)
print(gm.by_group)
# Out:
# 0.9900779588944011
# Gender
# 0    0.985612
# 1    0.989987
# 2    0.990436
# 3    0.989427
# 4    0.987882
# 5           1
# Name: accuracy_score, dtype: object

# %%
gm = MetricFrame(accuracy_score, y, y_pred, sensitive_features=X['Race'])
print(gm.overall)
print(gm.by_group)
# Out:
# 0.9900779588944011
# Race
# 0    0.982343
# 1     0.99314
# 2     0.99116
# 3    0.992806
# 4           1
# 5           1
# 6     0.98962
# Name: accuracy_score, dtype: object

# %%
gm = MetricFrame(accuracy_score, y, y_pred, sensitive_features=X['CreditScore'])
print(gm.overall)
print(gm.by_group)
# Out:
# Found 180 subgroups. Evaluation may be slow
# 0.9900779588944011
# CreditScore
# 620    0.997908
# 621    0.978261
# 622    0.983707
# 623    0.989733
# 624    0.959641
#          ...
# 795     0.99684
# 796    0.996885
# 797    0.998447
# 798           1
# 799           1
# Name: accuracy_score, Length: 180, dtype: object

# %%
gm = MetricFrame(accuracy_score, y, y_pred, sensitive_features=X['Job'])
print(gm.overall)
print(gm.by_group)
# Out:
# Found 1042 subgroups. Evaluation may be slow
# 0.9900779588944011
# Job
# 0              1
# 1       0.955224
# 2              1
# 3              1
# 4              1
#           ...
# 1037           1
# 1038           1
# 1039           1
# 1040           1
# 1041           1
# Name: accuracy_score, Length: 1042, dtype: object

# %%
gm = MetricFrame(accuracy_score, y, y_pred, sensitive_features=X['DAR'])
print(gm.overall)
print(gm.by_group)
# Out:
# Found 121 subgroups. Evaluation may be slow
# 0.9900779588944011
# DAR
# 0.000000e+00           1
# 2.775558e-17    0.987658
# 5.551115e-17           1
# 9.714451e-17           1
# 1.804112e-16           1
#                   ...
# 4.375000e-01           1
# 1.000000e+00           1
# 1.000000e+00         0.9
# 1.000000e+00    0.988725
# 1.000000e+00           1
# Name: accuracy_score, Length: 121, dtype: object

# %%
gm = MetricFrame(accuracy_score, y, y_pred, sensitive_features=X['Credit_Incidents'])
print(gm.overall)
print(gm.by_group)
# Out:
# 0.9900779588944011
# Credit_Incidents
# 0.000000    0.994529
# 0.166667    0.994911
# 0.333333    0.993446
# 0.500000    0.994422
# 0.666667    0.971411
# 0.833333    0.983566
# 1.000000           1
# Name: accuracy_score, dtype: object
